# %%
from sympy import *

# %%
x, k, m, c = symbols('x k m c')

# %%
f = integrate(-(x - k)/c, x)
f
# Out:
# k*x/c - x**2/(2*c)

# %%
plot(f.subs({k: .1, c: .1}), (x, -1, 1))

# %%
Fi = integrate(f, x)
Fi
# Out:
# k*x**2/(2*c) - x**3/(6*c)

# %%
simplify(f/Fi)
# Out:
# 3*(2*k - x)/(x*(3*k - x))

# %%
plot(simplify(f/Fi).subs(k, .1).subs(c, .1), (x, -1, 1), title='f(x)')

# %%
g = 1/(sqrt(2*pi)) * exp(-x**2/2)
plot(diff(g, x), (x, -1, 1))

# %%
g = 1 * exp(-1 * abs(x)/2)
plot(g, (x, -1, 1))
